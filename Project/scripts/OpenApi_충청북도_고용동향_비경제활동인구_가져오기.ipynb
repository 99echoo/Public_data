# %%
import requests
import csv

# CSV 파일 저장 경로 설정
csv_file_path = "C:/Users/user/Desktop/Public_data/2024_충청북도_공공데이터_창업경진대회/충청북도_고용동향_비경제활동인구.csv"

# API 요청 기본 정보
url = 'http://apis.data.go.kr/6430000/emplTrendInacPopulService/getEmplTrendInacPopul'
decoding = 'mW18J6e5gQ61JGt5YYgjiPhATkpOt/KJJxNjPUP3j/RoQF4VCrtduhvdMHs52rOOgdKh15FqXmnsPSsk8avWWA=='

# 칼럼명 동적 생성 함수
def fetch_initial_columns(json_data):
    first_item = json_data['body'][0]  # 첫 번째 아이템 접근
    return list(first_item.keys())  # 모든 키를 칼럼명으로 사용

# 최초 API 호출을 통해 칼럼명 설정
initial_params = {
    'serviceKey' : decoding, 
    'currentPage' : '1',
    'perPage' : '10',
}
response = requests.get(url, params=initial_params)
response.raise_for_status()
json_data = response.json()
columns = fetch_initial_columns(json_data)

# CSV 파일 오픈 및 헤더 작성
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(columns)  # 칼럼명을 헤더로 작성
    
    # 페이지별 데이터 수집 및 CSV 파일에 작성
    for page in range(1, 100):
        params = {
            'serviceKey' : decoding,
            'currentPage' : page,
            'perPage' : '10'
        }
        response = requests.get(url, params=params)
        response.raise_for_status()
        json_data = response.json()
        
        # 각 항목별 데이터를 CSV 파일에 추가
        for item in json_data['body']:
            row = [item.get(col, '') for col in columns]  # 동적 칼럼명을 사용하여 데이터 추출
            writer.writerow(row)

print(f"CSV 파일이 저장된 위치: {csv_file_path}")
# Out:
# CSV 파일이 저장된 위치: C:/Users/user/Desktop/Public_data/2024_충청북도_공공데이터_창업경진대회/충청북도_고용동향_비경제활동인구.csv

# %%
import pandas as pd

data = pd.read_csv("C:/Users/user/Desktop/Public_data/2024_충청북도_공공데이터_창업경진대회/충청북도_고용동향_비경제활동인구.csv")

data
# Out:
#     YEAR  MT  CT_ECNMY_ACT_POPLTN_CO
# 0   2019   1                     529
# 1   2019   2                     513
# 2   2019   3                     499
# 3   2019   4                     481
# 4   2019   5                     464
# 5   2019   6                     476
# 6   2019   7                     478
# 7   2019   8                     485
# 8   2019   9                     490
# 9   2019  10                     486
# 10  2019  11                     493
# 11  2019  12                     509
# 12  2020   1                     510
# 13  2020   2                     506
# 14  2020   3                     494
# 15  2020   4                     493
# 16  2020   5                     471
# 17  2020   6                     466
# 18  2020   7                     473
# 19  2020   8                     485
# 20  2020   9                     481
# 21  2020  10                     490
