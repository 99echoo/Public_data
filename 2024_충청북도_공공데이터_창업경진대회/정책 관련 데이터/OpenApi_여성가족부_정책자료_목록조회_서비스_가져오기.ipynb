# %% [markdown]
# ## 한페이지만 불러오는 코드

# %%
import requests
import json
import csv

url = 'http://apis.data.go.kr/1383000/policy/subjectList'
params = {
    'serviceKey' : 'mW18J6e5gQ61JGt5YYgjiPhATkpOt/KJJxNjPUP3j/RoQF4VCrtduhvdMHs52rOOgdKh15FqXmnsPSsk8avWWA==',
    'pageNo' : '20',
    'type' : 'json',
    'numOFRows' : '10',
    'apiType' : 'youApi'
}

response = requests.get(url, params=params)

# JSON 파싱
json_data = response.json()  # 직접 JSON 파싱 메소드 사용
items = json_data['body'][0]['items']['item']

# CSV 파일로 저장
csv_file = "C:/Users/user/Desktop/공모전/DataFrame.csv"
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['담당자 이름', '부서명', '제목', '등록일', '전화번호', '조회수', 'URL'])
    for item in items:
        writer.writerow([item['chrgrNm'], item['deptNm'], item['title'], item['regDt'], item['telNo'], item['inqCnt'], item['url']])

csv_file
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16372\514989805.py in <module>
#      24     writer.writerow(['담당자 이름', '부서명', '제목', '등록일', '전화번호', '조회수', 'URL'])
#      25     for item in items:
# ---> 26         writer.writerow([item['chrgrNm'], item['deptNm'], item['title'], item['regDt'], item['telNo'], item['inqCnt'], item['url']])
#      27
#      28 csv_file
#
# KeyError: 'telNo'

# %% [markdown]
# ## 전체 데이터 로드

# %%
import requests
import json
import csv

# CSV 파일 저장 경로 설정
csv_file_path = "C:/Users/user/Desktop/공모전/DataFrame.csv"

# API 요청 기본 정보
url = 'http://apis.data.go.kr/1383000/policy/subjectList'
api_types = ['youApi', 'equApi', 'famApi', 'proApi', 'othApi']  # 사용할 apiType 목록

# CSV 파일 오픈 및 헤더 작성
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['담당자 이름', '부서명', '제목', '등록일', '전화번호', '조회수', 'URL'])
    
    # 각 API 타입과 페이지에 대해 반복
    for api_type in api_types:
        params = {
            'serviceKey' : 'mW18J6e5gQ61JGt5YYgjiPhATkpOt/KJJxNjPUP3j/RoQF4VCrtduhvdMHs52rOOgdKh15FqXmnsPSsk8avWWA==',
            'type' : 'json',
            'numOFRows' : '10',
            'apiType' : api_type
        }
        for page in range(1, 100):
            params['pageNo'] = page
            try:
                response = requests.get(url, params=params)
                response.raise_for_status()  # 요청 실패 시 예외 발생
                json_data = response.json()
                items = json_data['body'][0]['items']['item']
        
            # 각 항목별 데이터를 CSV 파일에 추가
                for item in items:
                    writer.writerow([item.get('chrgrNm', ''), item.get('deptNm', ''), item.get('title', ''),
                                 item.get('regDt', ''), item.get('telNo', ''), item.get('inqCnt', ''),
                                 item.get('url', '')])
            except (requests.RequestException, ValueError) as e:
                print(f"페이지 {page} 처리 중 오류 발생: {e}")

print(f"CSV 파일이 저장된 위치: {csv_file_path}")
# Out:
# CSV 파일이 저장된 위치: C:/Users/user/Desktop/공모전/DataFrame.csv

# %%
import pandas as pd

data = pd.read_csv("C:/Users/user/Desktop/공모전/DataFrame.csv")
data
# Out:
#      담당자 이름       부서명                                        제목         등록일  \
# 0       손동락  청소년보호환경과                             청소년유해환경감시단 현황  2024-04-03
# 1       최윤정  청소년활동안전과                        2023년 청소년수련활동 인증현황  2024-04-02
# 2       김태형  청소년보호환경과                  청소년유해매체물 일반심의기준 및 개별심의기준  2024-04-01
# 3       오동훈  청소년활동진흥과             우수 청소년활동  프로그램 지원사업 운영기관 선정결과  2024-04-01
# 4       오동훈  청소년활동진흥과             우수 청소년활동 프로그램 지원사업 운영기관 모집 공고  2024-04-01
# ...     ...       ...                                       ...         ...
# 1738     이진   기획재정담당관                          여성가족부 정부 승인통계 현황  2010-10-19
# 1739     이진   기획재정담당관                           여성가족부 정부승인통계 현황  2010-10-19
# 1740     이진   기획재정담당관               여성가족부 정부승인통계 현황(2010.10.18)  2010-10-19
# 1741    하손숙    청소년보호과  2010년도 흡연청소년 건강상담 및 금연침 무료시술사업 지정 한의명 명단  2010-05-04
# 1742    양종윤   기획재정담당관                    2010년도 예산개요 및 주요사업설명자료  2010-03-24
#
#               전화번호    조회수                                                URL
# 0     02-2100-6299   6455  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1     02)2100-6267    139  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 2     02-2100-6302    883  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 3     02-2100-6254   4068  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 4     02-2100-6254   3692  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# ...            ...    ...                                                ...
# 1738  02)2075-4566    688  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1739  02)2075-4566    683  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1740  02)2075-4566    691  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1741  02)2075-8685  12382  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1742  02)2075-4566  11564  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
#
# [1743 rows x 7 columns]

# %%
import requests
import json
import csv

# CSV 파일 저장 경로 설정
##### 저장할 CSV파일의 경로를 이곳에 설정하세요 ##### 
csv_file_path = "C:/Users/user/Desktop/공모전/DataFrame.csv"


# API 요청 기본 정보
### API url과 필요한 변수명을 List로 만드세요 ###
### 파라미터의 변수의 종류는 메타데이터를 참고하세요 ###
url = 'http://apis.data.go.kr/1383000/policy/subjectList'
type = 'json'
api_types = ['youApi', 'equApi', 'famApi', 'proApi', 'othApi']  # 사용할 apiType 목록
### param2 = []
### param3 = []

### encoding = '발급받은 인코딩 인증키를 복사하여 붙여넣기 해 주세요.'
decoding = 'mW18J6e5gQ61JGt5YYgjiPhATkpOt/KJJxNjPUP3j/RoQF4VCrtduhvdMHs52rOOgdKh15FqXmnsPSsk8avWWA=='


# 최초의 API 호출로부터 칼럼명 동적 생성
def fetch_initial_columns(url, params):
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        json_data = response.json()
        first_item = json_data['body'][0]['items']['item'][0]  # 첫 번째 아이템 접근
        return list(first_item.keys())  # 모든 키를 칼럼명으로 사용
    except (requests.RequestException, ValueError) as e:
        print(f"초기 칼럼명 추출 실패: {e}")
        return []

# CSV 파일 오픈 및 헤더 작성
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # 최초 API 호출을 통해 칼럼명 설정
    initial_params = {
        'serviceKey' : decoding, 
        'type' : type,
        'numOFRows' : '10',
        'pageNo' : '1',
        'apiType' : api_types[0]  # 첫 번째 API 타입으로 칼럼명 결정
    }
    columns = fetch_initial_columns(url, initial_params)
    writer.writerow(columns)
    
    # 각 API 타입과 페이지에 대해 반복
    for api_type in api_types:
        params = {
            'serviceKey' : decoding,
            'type' : type,
            'numOFRows' : '10',
            'apiType' : api_type
        }
        for page in range(1, 100):
            params['pageNo'] = page
            try:
                response = requests.get(url, params=params)
                response.raise_for_status()  # 요청 실패 시 예외 발생
                json_data = response.json()
                items = json_data['body'][0]['items']['item']
        
                # 각 항목별 데이터를 CSV 파일에 추가
                for item in items:
                    row = [item.get(col, '') for col in columns]  # 동적 칼럼명을 사용하여 데이터 추출
                    writer.writerow(row)
            except (requests.RequestException, ValueError) as e:
                print(f"페이지 {page} 처리 중 오류 발생: {e}")

print(f"CSV 파일이 저장된 위치: {csv_file_path}")
# Out:
# CSV 파일이 저장된 위치: C:/Users/user/Desktop/공모전/DataFrame.csv

# %%
import pandas as pd

data = pd.read_csv("C:/Users/user/Desktop/공모전/DataFrame.csv")
data
# Out:
#      chrgrNm    deptNm                                     title       regDt  \
# 0        손동락  청소년보호환경과                             청소년유해환경감시단 현황  2024-04-03
# 1        최윤정  청소년활동안전과                        2023년 청소년수련활동 인증현황  2024-04-02
# 2        김태형  청소년보호환경과                  청소년유해매체물 일반심의기준 및 개별심의기준  2024-04-01
# 3        오동훈  청소년활동진흥과             우수 청소년활동  프로그램 지원사업 운영기관 선정결과  2024-04-01
# 4        오동훈  청소년활동진흥과             우수 청소년활동 프로그램 지원사업 운영기관 모집 공고  2024-04-01
# ...      ...       ...                                       ...         ...
# 1739      이진   기획재정담당관                          여성가족부 정부 승인통계 현황  2010-10-19
# 1740      이진   기획재정담당관                           여성가족부 정부승인통계 현황  2010-10-19
# 1741      이진   기획재정담당관               여성가족부 정부승인통계 현황(2010.10.18)  2010-10-19
# 1742     하손숙    청소년보호과  2010년도 흡연청소년 건강상담 및 금연침 무료시술사업 지정 한의명 명단  2010-05-04
# 1743     양종윤   기획재정담당관                    2010년도 예산개요 및 주요사업설명자료  2010-03-24
#
#                                                    cont         telNo  inqCnt  \
# 0     <span style="font-family: 돋움;">지역사회 내에서 각종 청소년...  02-2100-6299    6468
# 1              <p>2023년 청소년수련활동 인증현황을 첨부와 같이 게재합니다.</p>  02)2100-6267     154
# 2     <p><span style="font-size: 10pt;">청소년보호법 제9조 및...  02-2100-6302     892
# 3     <div><span style="font-size: 10pt;">우수 청소년활동 프...  02-2100-6254    4082
# 4     <p><span style="font-size: 10pt;">우수 청소년활동 프로그...  02-2100-6254    3701
# ...                                                 ...           ...     ...
# 1739                               여성가족부 정부 승인통계 현황입니다.  02)2075-4566     692
# 1740                                여성가족부 정부승인통계 현황입니다.  02)2075-4566     687
# 1741                                여성가족부 정부승인통계 현황입니다.  02)2075-4566     695
# 1742  여성가족부는 대한한의사협회와 공동으로 흡연 청소년에 대한 건강상담과 금연침 무료시술...  02)2075-8685   12386
# 1743                             2010년도 예산개요 및 주요사업설명자료  02)2075-4566   11568
#
#                                                     url
# 0     http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1     http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 2     http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 3     http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 4     http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# ...                                                 ...
# 1739  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1740  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1741  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1742  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1743  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
#
# [1744 rows x 8 columns]

# %%
data_1 = data[data['title'].str.contains('지원', na=False, case=False)]
data_1
# Out:
#      chrgrNm     deptNm                                title       regDt  \
# 3        오동훈   청소년활동진흥과        우수 청소년활동  프로그램 지원사업 운영기관 선정결과  2024-04-01
# 4        오동훈   청소년활동진흥과        우수 청소년활동 프로그램 지원사업 운영기관 모집 공고  2024-04-01
# 11       김서영   청소년자립지원과                위기청소년 지원기관 이용자 생활실태조사  2024-01-15
# 15       이유정   청소년자립지원과                 청소년쉼터, 청소년자립지원관 운영현황  2024-01-15
# 21      박윤호   학교밖청소년지원과                  2023년 위기청소년 특별지원 사업  2023-10-05
# ...      ...        ...                                  ...         ...
# 1346     박선옥      권익지원과              여성.아동 폭력 피해자 전담 지원기관 현황  2011-02-17
# 1541     김수현    법무감사담당관      감사원 특정감사(고용장려금 지원 및 관리실태) 결과보고서  2019-11-13
# 1582     김수현    법무감사담당관  감사원 성과감사(보호대상 청소년 지원 및 교화 실태) 결과보고서  2018-10-25
# 1590     김수현    법무감사담당관    감사원 성과감사(일.가정 양립 지원제도 운영실태) 결과보고서  2018-07-12
# 1594     김수현    법무감사담당관        2018년도 산하기관 감사결과(이주배경청소년지원재단)  2018-06-20
#
#                                                    cont         telNo  inqCnt  \
# 3     <div><span style="font-size: 10pt;">우수 청소년활동 프...  02-2100-6254    4082
# 4     <p><span style="font-size: 10pt;">우수 청소년활동 프로그...  02-2100-6254    3701
# 11    <p>2021년 위기청소년 실태조사&nbsp;</p>\r\n<p>발간등록번호 11-...  02)2100-6280    4697
# 15    <p>가출 등 위기청소년을 조기에 발굴하고 보호하여 자립할 수 있도록 지원하기 위하...  02-2100-6281   18325
# 21    <p><span style="font-weight: bold;">2023년 위기청소...  02-2100-6315   12896
# ...                                                 ...           ...     ...
# 1346  '11.2월 현재&nbsp;해바라기아동센터, 원스톱지원센터, 해바라기 여성아동센터 ...  02)2075-8768    5996
# 1541  <p><br></p> \r\n<p><br></p> \r\n<p>감사원&nbsp;특정...  02)2100-6096     680
# 1582  <p><br></p> \r\n<p><br></p> \r\n<p>감사원 성과감사 결과...  02)2100-6096     711
# 1590  <p><br></p> \r\n<p>감사원 성과감사 결과보고서를 게시합니다.</p> ...  02)2100-6096    1250
# 1594  <p>&nbsp;</p> \r\n<p>&nbsp;2018년도 산하기관 감사결과(이주...  02)2100-6096     751
#
#                                                     url
# 3     http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 4     http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 11    http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 15    http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 21    http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# ...                                                 ...
# 1346  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1541  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1582  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1590  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
# 1594  http://www.mogef.go.kr/mp/pcd/mp_pcd_s001d.do?...
#
# [173 rows x 8 columns]
